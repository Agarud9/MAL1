# %% [markdown]
# # Candidate Test 2022 Analysis Part 1
#
# This exercise focuses on the candidate tests from two television networks: DR and TV2. Data from both tests have been given on a scale of five responses (-2, -1, 0, 1, 2).
#
# ---
#
# There are 6 datasets included in this exercise:
#
# - `alldata.xlsx`: Contains responses from both TV stations.
# - `drdata.xlsx`: Contains responses from DR.
# - `drq.xlsx`: Contains questions from DR.
# - `tv2data.xlsx`: Contains responses from TV2.
# - `tv2q.xlsx`: Contains questions from TV2.
# - `electeddata.xlsx`: Contains responses from both TV stations for candidates who were elected to the parliament. Note that 9 members are missing; 7 of them didn't take any of the tests. Additionally, some notable figures like Mette F. and Lars Løkke did not participate in any of the tests.
#
# ---
#
# It's entirely up to you how you approach this data, but at a *minimum*, your analysis should include:
# - Age of the candidates grouped by parties.
# - An overview of the most "confident" candidates, i.e., those with the highest proportion of "strongly agree" or "strongly disagree" responses.
# - Differences in responses between candidates, both inter-party and intra-party, along with an explanation of which parties have the most internal disagreements.
# - Classification models to predict candidates' party affiliations. Investigate if there are any candidates who seem to be in the "wrong" party based on their political landscape positions. You must use the following three algorithms: **Decision Tree, Random Forrest, and Gradient Boosted Tree**, and **two other** classification algorithms of your choice.
#
# ---
#
# The following parties are represented:
#
# | Party letter | Party name | Party name (English) | Political position |
# | :-: | :-: | :-: | :-: |
# | A | Socialdemokratiet | Social Democrats | Centre-left |
# | V | Venstre | Danish Liberal Party | Centre-right |
# | M | Moderaterne | Moderates | Centre-right |
# | F | Socialistisk Folkeparti | Socialist People's Party | Left-wing |
# | D | Danmarksdemokraterne | Denmark Democrats | Right-wing |
# | I | Liberal Alliance | Liberal Alliance | Right-wing |
# | C | Konservative | Conservative People's Party | Right-wing |
# | Æ | Enhedslisten | Red-Green Alliance | Far-left |
# | B | Radikale Venstre | Social Liberal Party | Centre-left |
# | D | Nye Borgerlige | New Right | Far-right |
# | Z | Alternativet | The Alternative | Centre-left |
# | O | Dansk Folkeparti | Danish People's Party | Far-right |
# | G | Frie Grønne | Free Greens | Centre-left |
# | K | Kristendemokraterne | Christian Democrats | Centre-right |
#
# Below you can see the results and the colors chosen to represent the parties. Use these colors in your analysis above.
#
# ![Alt text](image-1.png)
#
#
# Others have undertaken similar analyses. You can draw inspiration from the following (use Google tranlsate if your Danish is rusty):
#
# - [Analysis of where individual candidates stand relative to each other and their parties](https://v2022.dumdata.dk/)
# - [Candidate Test 2022 – A deep dive into the data](https://kwedel.github.io/kandidattest2022/)
# - [The Political Landscape 2019](https://kwedel.github.io/kandidattest2019/)

# %% [markdown]
# **Age of the candidates grouped by parties.**

# %%
import pandas as pd
import xlrd

tv2data = pd.read_excel('tv2data.xlsx')
tv2data = tv2data[['parti', 'alder']]

# Drop individual candidates, who are not a part of a party
tv2data = tv2data[tv2data['parti'] != 'Løsgænger']

tv2data = tv2data.groupby('parti').mean()
tv2data['alder'] = tv2data['alder'].round(1)
tv2data = tv2data.sort_values(by='alder', ascending=False)

display(tv2data)
# Out:
#                                              alder
# parti
# Danmarksdemokraterne                          51.2
# Kristendemokraterne                           50.8
# Alternativet                                  47.3
# Venstre                                       47.3
# Nye Borgerlige                                46.9
# Radikale Venstre                              45.5
# Dansk Folkeparti                              45.3
# Moderaterne                                   44.8
# Socialdemokratiet                             44.6
# Det Konservative Folkeparti                   42.8
# Socialistisk Folkeparti                       41.8
# Enhedslisten                                  40.8
# Liberal Alliance                              37.4
# Frie Grønne, Danmarks Nye Venstrefløjsparti   33.6

# %% [markdown]
# **An overview of the most "confident" candidates, i.e., those with the highest proportion of "strongly agree" or "strongly disagree" responses.**

# %%
allCandidates = pd.read_excel('alldata.xlsx')
allCandidates = allCandidates.drop(columns=['alder', 'storkreds'])
confidentCandidates = allCandidates

# Define a function to count occurrences of 2 or -2 in each row
def count_2_or_minus_2(row):
    # Count how many times 2 or -2 appears in the row and return the count
    return (row == 2).sum() + (row == -2).sum()

# Apply the function to each row to create the new column, axis=1 means apply the function to each row
confidentCandidates['confident_answers'] = confidentCandidates.apply(count_2_or_minus_2, axis=1)

confidentCandidates = confidentCandidates[['navn', 'parti', 'confident_answers']]
confidentCandidates = confidentCandidates.sort_values(by='confident_answers', ascending=False)
confidentCandidates = confidentCandidates.head(10).reset_index(drop=True)

display(confidentCandidates)
# Out:
#                   navn                                        parti  \
# 0         Sarah Nørris                                 Enhedslisten
# 1        Søren Vanting                  Det Konservative Folkeparti
# 2  Kim Andkjær Doberck                               Nye Borgerlige
# 3           Rashid Ali  Frie Grønne, Danmarks Nye Venstrefløjsparti
# 4    Mohamed Abdikarim  Frie Grønne, Danmarks Nye Venstrefløjsparti
# 5          Jan Filbært                                 Enhedslisten
# 6     Elise Bjerkrheim  Frie Grønne, Danmarks Nye Venstrefløjsparti
# 7           John Bjerg                               Nye Borgerlige
# 8  Lone Vase Langballe                             Dansk Folkeparti
# 9       Frank Sørensen                             Dansk Folkeparti
#
#    confident_answers
# 0                 49
# 1                 49
# 2                 44
# 3                 43
# 4                 43
# 5                 42
# 6                 42
# 7                 42
# 8                 42
# 9                 42

# %% [markdown]
# **An overview of the most "neutral" candidates, i.e., those with the highest proportion of "neutral" responses.**

# %%
allCandidates = pd.read_excel('alldata.xlsx')
allCandidates = allCandidates.drop(columns=['alder', 'storkreds'])
neutralCandidates = allCandidates

# Define a function to count occurrences of 0 in each row
def count_0(row):
    # Count how many times 0 in the row and return the count
    return (row == 0).sum() 

# Apply the function to each row to create the new column, axis=1 means apply the function to each row
neutralCandidates['confident_answers'] = neutralCandidates.apply(count_0, axis=1)

neutralCandidates = neutralCandidates[['navn', 'parti', 'confident_answers']]
neutralCandidates = neutralCandidates.sort_values(by='confident_answers', ascending=False)
neutralCandidates = neutralCandidates.head(10).reset_index(drop=True)

display(neutralCandidates)
# Out:
#                          navn                 parti  confident_answers
# 0       Barbara Krarup Hansen     Socialdemokratiet                 32
# 1        Thorkild Holmboe-Hay     Socialdemokratiet                 28
# 2  Kenneth Fredslund Petersen  Danmarksdemokraterne                 23
# 3               Anne Hegelund          Enhedslisten                 23
# 4           Kasper Sten Krebs          Alternativet                 21
# 5                Dorthe Hecht          Enhedslisten                 15
# 6               Kim Rasmussen           Moderaterne                 14
# 7                Malte Larsen     Socialdemokratiet                 14
# 8                  Claus Buch               Venstre                 14
# 9     Carsten Damgaard Møller           Moderaterne                 14

# %% [markdown]
# **Differences in responses between candidates, both inter-party and intra-party, along with an explanation of which parties have the most internal disagreements.**

# %%
responses = pd.read_excel('alldata.xlsx')
responses = responses.drop(columns=['alder', 'storkreds', 'navn'])

# Drop individual candidates, who are not a part of a party
responses = responses[responses['parti'] != 'Løsgænger']

# INTER PARTY

responsesWithoutParty = responses.drop(columns=['parti'])

# Std for all responses 
responsesVariance = responsesWithoutParty.std()
print("DIfferences in responses inter-party")
display(responsesVariance)

sortedDifferences = responsesVariance.sort_values(ascending=False)

# Display the top 10 questions where the candidates disagreed most
print("Top 10 contradictory questions:")
display(sortedDifferences.head(10))

# --------------------------------------------------------------------------------------------------------------------------------------------------------------

# INTRA PARTY 

# Std for each response in each party
responsesVariationsGroupedByParty = responses.groupby('parti').std()
print("Differences in responses between candidates intra-party")
display(responsesVariationsGroupedByParty)

# Mean of std of responses in each party
responsesVariationsGroupedByPartyMean = responsesVariationsGroupedByParty.mean(axis=1)

# Sort the mean values in descending order
sortedMeans = responsesVariationsGroupedByPartyMean.sort_values(ascending=False)

# Display the top 10 parties with their mean standard deviation
print("Top 10 Parties with most internal disagreements:")
display(sortedMeans.head(10))
# Out:
# DIfferences in responses inter-party
# 530    1.422987
# 531    1.616885
# 533    1.528374
# 534    1.380771
# 535    1.350876
# 537    1.543304
# 538    1.333816
# 540    1.522558
# 541    1.567395
# 543    1.525814
# 544    1.604332
# 545    1.379807
# 546    1.621371
# 547    1.458963
# 548    1.404736
# 550    1.588156
# 551    1.482317
# 552    1.462314
# 553    1.384817
# 555    1.658040
# 556    1.648914
# 557    1.178702
# 559    1.505487
# 561    1.405903
# 563    1.427938
# 1a     1.452737
# 1b     1.364897
# 2a     1.151963
# 2b     1.440227
# 3a     1.410110
# 3b     1.579852
# 4a     1.378342
# 4b     1.185192
# 5a     0.959794
# 5b     0.928012
# 6a     1.605280
# 6b     1.604415
# 7a     1.548218
# 7b     1.095970
# 8a     0.831373
# 8b     0.951641
# 9a     1.410224
# 9b     1.015459
# 10a    1.235777
# 10b    1.617698
# 11a    1.472809
# 11b    1.602712
# 12a    1.027731
# 12b    1.220717
# dtype: float64
# Top 10 contradictory questions:
# 555    1.658040
# 556    1.648914
# 546    1.621371
# 10b    1.617698
# 531    1.616885
# 6a     1.605280
# 6b     1.604415
# 544    1.604332
# 11b    1.602712
# 550    1.588156
# dtype: float64
# Differences in responses between candidates intra-party
#                                                   530       531       533  \
# parti
# Alternativet                                 0.477442  0.983123  0.308188
# Danmarksdemokraterne                         0.727000  0.545250  0.901284
# Dansk Folkeparti                             0.935414  0.837574  0.867497
# Det Konservative Folkeparti                  1.081178  0.329489  1.271191
# Enhedslisten                                 0.258509  0.381932  0.274823
# Frie Grønne, Danmarks Nye Venstrefløjsparti  0.271746  0.271746  0.000000
# Kristendemokraterne                          1.086556  1.319029  1.110608
# Liberal Alliance                             0.747667  0.167802  1.145700
# Moderaterne                                  0.983310  0.957882  1.293242
# Nye Borgerlige                               0.458471  0.237635  0.981396
# Radikale Venstre                             0.578915  0.939605  0.446606
# Socialdemokratiet                            0.960041  0.986002  1.103444
# Socialistisk Folkeparti                      0.352454  0.402888  0.705495
# Venstre                                      0.859292  0.501718  1.139697
#
#                                                   534       535       537  \
# parti
# Alternativet                                 0.490064  1.125744  0.569463
# Danmarksdemokraterne                         0.725966  0.494717  0.967179
# Dansk Folkeparti                             0.596902  0.708908  1.172604
# Det Konservative Folkeparti                  0.673504  0.389209  0.784341
# Enhedslisten                                 1.291902  0.625421  0.368362
# Frie Grønne, Danmarks Nye Venstrefløjsparti  0.470679  0.429669  0.000000
# Kristendemokraterne                          0.912235  0.943220  1.309307
# Liberal Alliance                             0.740572  0.630652  0.302166
# Moderaterne                                  0.297102  0.496796  0.882137
# Nye Borgerlige                               0.529891  0.196039  0.756151
# Radikale Venstre                             0.122169  1.021479  1.005413
# Socialdemokratiet                            0.517794  0.607359  0.698454
# Socialistisk Folkeparti                      0.302166  0.568497  0.320455
# Venstre                                      0.509660  0.613951  0.696685
#
#                                                   538       540       541  \
# parti
# Alternativet                                 1.312019  1.300419  1.033584
# Danmarksdemokraterne                         0.419137  0.664411  0.363500
# Dansk Folkeparti                             0.614452  1.094979  0.708908
# Det Konservative Folkeparti                  0.142119  0.536193  1.028573
# Enhedslisten                                 1.292833  0.437293  0.538245
# Frie Grønne, Danmarks Nye Venstrefløjsparti  0.651625  0.859338  0.884047
# Kristendemokraterne                          1.167703  1.199351  1.309307
# Liberal Alliance                             0.000000  0.167802  0.882777
# Moderaterne                                  0.354169  0.739228  1.208756
# Nye Borgerlige                               0.140028  0.325396  0.691687
# Radikale Venstre                             1.212777  0.957014  1.277966
# Socialdemokratiet                            0.899077  0.681602  1.199550
# Socialistisk Folkeparti                      0.626535  0.422944  0.561719
# Venstre                                      0.259086  0.616632  0.961314
#
#                                                   543  ...        8a  \
# parti                                                  ...
# Alternativet                                 0.856771  ...  0.789747
# Danmarksdemokraterne                         0.763271  ...  0.577350
# Dansk Folkeparti                             1.226826  ...  0.968026
# Det Konservative Folkeparti                  0.858431  ...  0.786484
# Enhedslisten                                 0.476007  ...  0.955992
# Frie Grønne, Danmarks Nye Venstrefløjsparti  0.325813  ...  1.176697
# Kristendemokraterne                          1.257036  ...  0.532890
# Liberal Alliance                             0.572127  ...  0.924589
# Moderaterne                                  0.771517  ...  0.696765
# Nye Borgerlige                               0.737244  ...  0.621825
# Radikale Venstre                             0.936230  ...  0.794030
# Socialdemokratiet                            1.052485  ...  0.599385
# Socialistisk Folkeparti                      0.440215  ...  0.586953
# Venstre                                      0.621267  ...  0.621267
#
#                                                    8b        9a        9b  \
# parti
# Alternativet                                 0.832949  0.765906  1.023911
# Danmarksdemokraterne                         0.651863  0.554804  0.570812
# Dansk Folkeparti                             1.023117  1.093036  1.158377
# Det Konservative Folkeparti                  0.809488  1.017881  0.976098
# Enhedslisten                                 1.048703  0.417366  0.899319
# Frie Grønne, Danmarks Nye Venstrefløjsparti  1.066987  0.928191  1.333590
# Kristendemokraterne                          0.972622  1.199351  1.206111
# Liberal Alliance                             0.976430  0.856228  0.819534
# Moderaterne                                  0.912235  0.923622  1.018984
# Nye Borgerlige                               0.621194  0.734580  0.623085
# Radikale Venstre                             0.858353  0.937678  0.973182
# Socialdemokratiet                            0.757393  0.790548  0.681994
# Socialistisk Folkeparti                      0.715981  0.587129  0.908779
# Venstre                                      0.733882  1.023182  0.769469
#
#                                                   10a       10b       11a  \
# parti
# Alternativet                                 1.076663  1.086698  1.200972
# Danmarksdemokraterne                         0.682250  0.276725  0.164399
# Dansk Folkeparti                             0.731344  0.765431  0.547878
# Det Konservative Folkeparti                  0.762579  0.683120  0.422515
# Enhedslisten                                 0.957153  0.337960  1.003142
# Frie Grønne, Danmarks Nye Venstrefløjsparti  1.555140  0.752432  1.070586
# Kristendemokraterne                          0.912235  1.074463  1.023816
# Liberal Alliance                             0.557464  0.259399  0.203997
# Moderaterne                                  0.676896  1.001741  0.680319
# Nye Borgerlige                               0.367290  0.930949  0.196039
# Radikale Venstre                             0.934296  1.165422  0.756399
# Socialdemokratiet                            0.790041  0.306309  0.516242
# Socialistisk Folkeparti                      0.679331  0.459769  0.936935
# Venstre                                      0.632818  1.025213  0.404188
#
#                                                   11b       12a       12b
# parti
# Alternativet                                 1.223174  1.078342  1.172773
# Danmarksdemokraterne                         0.314800  0.650710  0.776919
# Dansk Folkeparti                             0.455503  0.928113  1.193805
# Det Konservative Folkeparti                  0.446248  0.783871  1.123408
# Enhedslisten                                 0.860504  1.061685  1.165339
# Frie Grønne, Danmarks Nye Venstrefløjsparti  1.017539  1.058301  1.250846
# Kristendemokraterne                          1.047368  0.923622  1.439649
# Liberal Alliance                             0.337142  0.649892  0.996993
# Moderaterne                                  0.696765  0.866528  1.164965
# Nye Borgerlige                               0.000000  0.941838  0.814573
# Radikale Venstre                             1.104041  0.845345  1.084407
# Socialdemokratiet                            0.462724  0.936218  0.885144
# Socialistisk Folkeparti                      0.887456  0.779659  0.866205
# Venstre                                      0.385293  0.600726  1.078662
#
# [14 rows x 49 columns]
# Top 10 Parties with most internal disagreements:
# parti
# Kristendemokraterne            1.030463
# Alternativet                   0.909648
# Moderaterne                    0.890754
# Dansk Folkeparti               0.888009
# Det Konservative Folkeparti    0.887302
# Radikale Venstre               0.857237
# Venstre                        0.834677
# Socialdemokratiet              0.825141
# Liberal Alliance               0.730710
# Enhedslisten                   0.678929
# dtype: float64

# %% [markdown]
# **Classification models to predict candidates' party affiliations. Investigate if there are any candidates who seem to be in the "wrong" party based on their political landscape positions. You must use the following three algorithms: *Decision Tree, Random Forrest, and Gradient Boosted Tree*, and *two other* classification algorithms of your choice.**

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

candidatesData = pd.read_excel('alldata.xlsx')
candidatesData = candidatesData.drop(columns=['alder', 'storkreds', 'navn'])

candidatesResponses = candidatesData.drop(columns=['parti'])
candidatesResponses.columns = candidatesResponses.columns.astype(str)


candidatesParty = candidatesData['parti']

# Use stratify to ensure that the class distribution is similar in both training and testing sets
X_train, X_test, y_train, y_test = train_test_split(candidatesResponses, candidatesParty, stratify=candidatesParty, random_state = 42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify= y_train, random_state=42)

# %%
# DECISION TREE

# Train the decision tree classifier
decisionTree = DecisionTreeClassifier(max_depth=5, random_state=42)
decisionTree.fit(X_train, y_train)

# Evaluate the model
y_pred = decisionTree.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)


# Predict party affiliations for new candidates
candidatesPartyAffiliationsTree = decisionTree.predict(X_test)

# Investigate potential misclassifications or candidates in the wrong party
for candidate, predictedParty, actualParty in zip(X_test.index, candidatesPartyAffiliationsTree, y_test):
   if actualParty != predictedParty:
    print(f"Candidate: {candidate}, Predicted Party: {predictedParty}, Actual Party: {actualParty}")
# Out:
# Accuracy: 0.6871165644171779
# Candidate: 164, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 357, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 778, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 806, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 230, Predicted Party: Venstre, Actual Party: Alternativet
# Candidate: 65, Predicted Party: Nye Borgerlige, Actual Party: Liberal Alliance
# Candidate: 519, Predicted Party: Nye Borgerlige, Actual Party: Venstre
# Candidate: 3, Predicted Party: Socialdemokratiet, Actual Party: Alternativet
# Candidate: 585, Predicted Party: Kristendemokraterne, Actual Party: Radikale Venstre
# Candidate: 692, Predicted Party: Alternativet, Actual Party: Radikale Venstre
# Candidate: 782, Predicted Party: Socialistisk Folkeparti, Actual Party: Alternativet
# Candidate: 392, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 263, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 92, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 42, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 817, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 351, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 600, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 863, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 635, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 559, Predicted Party: Løsgænger, Actual Party: Nye Borgerlige
# Candidate: 8, Predicted Party: Enhedslisten, Actual Party: Løsgænger
# Candidate: 785, Predicted Party: Kristendemokraterne, Actual Party: Alternativet
# Candidate: 176, Predicted Party: Det Konservative Folkeparti, Actual Party: Liberal Alliance
# Candidate: 419, Predicted Party: Venstre, Actual Party: Danmarksdemokraterne
# Candidate: 770, Predicted Party: Alternativet, Actual Party: Radikale Venstre
# Candidate: 480, Predicted Party: Kristendemokraterne, Actual Party: Radikale Venstre
# Candidate: 767, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 375, Predicted Party: Enhedslisten, Actual Party: Socialistisk Folkeparti
# Candidate: 680, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 763, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 822, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 664, Predicted Party: Alternativet, Actual Party: Socialistisk Folkeparti
# Candidate: 781, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 535, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 56, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 536, Predicted Party: Alternativet, Actual Party: Kristendemokraterne
# Candidate: 48, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 43, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 500, Predicted Party: Alternativet, Actual Party: Enhedslisten
# Candidate: 372, Predicted Party: Det Konservative Folkeparti, Actual Party: Liberal Alliance
# Candidate: 816, Predicted Party: Venstre, Actual Party: Dansk Folkeparti
# Candidate: 688, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 301, Predicted Party: Socialistisk Folkeparti, Actual Party: Radikale Venstre
# Candidate: 250, Predicted Party: Liberal Alliance, Actual Party: Venstre
# Candidate: 582, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 389, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 707, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 315, Predicted Party: Danmarksdemokraterne, Actual Party: Venstre
# Candidate: 659, Predicted Party: Det Konservative Folkeparti, Actual Party: Liberal Alliance
# Candidate: 843, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 575, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 652, Predicted Party: Det Konservative Folkeparti, Actual Party: Kristendemokraterne
# Candidate: 823, Predicted Party: Alternativet, Actual Party: Kristendemokraterne
# Candidate: 59, Predicted Party: Socialdemokratiet, Actual Party: Kristendemokraterne
# Candidate: 219, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 571, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 442, Predicted Party: Liberal Alliance, Actual Party: Kristendemokraterne
# Candidate: 289, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 366, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 650, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 563, Predicted Party: Det Konservative Folkeparti, Actual Party: Nye Borgerlige
# Candidate: 579, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 522, Predicted Party: Kristendemokraterne, Actual Party: Venstre
# Candidate: 534, Predicted Party: Alternativet, Actual Party: Kristendemokraterne
# Candidate: 444, Predicted Party: Dansk Folkeparti, Actual Party: Kristendemokraterne
# Candidate: 438, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 651, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 715, Predicted Party: Radikale Venstre, Actual Party: Alternativet
# Candidate: 568, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 261, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 765, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 649, Predicted Party: Venstre, Actual Party: Moderaterne
# Candidate: 347, Predicted Party: Nye Borgerlige, Actual Party: Danmarksdemokraterne
# Candidate: 272, Predicted Party: Nye Borgerlige, Actual Party: Liberal Alliance

# %%
from sklearn.ensemble import RandomForestClassifier

# RANDOM FOREST

forest = RandomForestClassifier(n_estimators = 200, max_depth = 6, 
                                max_features = 20, random_state = 42)
forest.fit(X_train, y_train)

# Evaluate the model
y_pred = forest.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)

# Predict party affiliations for new candidates
candidatesPartyAffiliationsForest = forest.predict(X_test)

# Investigate potential misclassifications or candidates in the wrong party
for candidate, predictedParty, actualParty in zip(X_test.index, candidatesPartyAffiliationsForest, y_test):
   if actualParty != predictedParty:
    print(f"Candidate: {candidate}, Predicted Party: {predictedParty}, Actual Party: {actualParty}")
# Out:
# Accuracy: 0.8957055214723927
# Candidate: 1, Predicted Party: Enhedslisten, Actual Party: Socialistisk Folkeparti
# Candidate: 65, Predicted Party: Nye Borgerlige, Actual Party: Liberal Alliance
# Candidate: 519, Predicted Party: Dansk Folkeparti, Actual Party: Venstre
# Candidate: 3, Predicted Party: Socialdemokratiet, Actual Party: Alternativet
# Candidate: 782, Predicted Party: Socialistisk Folkeparti, Actual Party: Alternativet
# Candidate: 92, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 42, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 76, Predicted Party: Alternativet, Actual Party: Socialistisk Folkeparti
# Candidate: 600, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 863, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 8, Predicted Party: Radikale Venstre, Actual Party: Løsgænger
# Candidate: 391, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 680, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 763, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 139, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 500, Predicted Party: Alternativet, Actual Party: Enhedslisten
# Candidate: 816, Predicted Party: Det Konservative Folkeparti, Actual Party: Dansk Folkeparti
# Candidate: 126, Predicted Party: Enhedslisten, Actual Party: Alternativet
# Candidate: 250, Predicted Party: Liberal Alliance, Actual Party: Venstre
# Candidate: 823, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 59, Predicted Party: Moderaterne, Actual Party: Kristendemokraterne
# Candidate: 219, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 442, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 289, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 568, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 347, Predicted Party: Dansk Folkeparti, Actual Party: Danmarksdemokraterne
# Candidate: 272, Predicted Party: Nye Borgerlige, Actual Party: Liberal Alliance

# %%
from sklearn.ensemble import GradientBoostingClassifier

# GRADIENT BOOSTED TREE

gbt = GradientBoostingClassifier(random_state = 42, n_estimators = 100,
                                max_depth = 2, learning_rate = 0.03)
gbt.fit(X_train, y_train)

# Evaluate the model
y_pred = gbt.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)

# Predict party affiliations for new candidates
candidatesPartyAffiliationsGBT = gbt.predict(X_test)

# Investigate potential misclassifications or candidates in the wrong party
for candidate, predictedParty, actualParty in zip(X_test.index, candidatesPartyAffiliationsGBT, y_test):
   if actualParty != predictedParty:
    print(f"Candidate: {candidate}, Predicted Party: {predictedParty}, Actual Party: {actualParty}")
# Out:
# Accuracy: 0.8957055214723927
# Candidate: 806, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 36, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 1, Predicted Party: Enhedslisten, Actual Party: Socialistisk Folkeparti
# Candidate: 296, Predicted Party: Alternativet, Actual Party: Radikale Venstre
# Candidate: 519, Predicted Party: Dansk Folkeparti, Actual Party: Venstre
# Candidate: 3, Predicted Party: Socialdemokratiet, Actual Party: Alternativet
# Candidate: 782, Predicted Party: Radikale Venstre, Actual Party: Alternativet
# Candidate: 92, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 42, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 76, Predicted Party: Alternativet, Actual Party: Socialistisk Folkeparti
# Candidate: 863, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 124, Predicted Party: Frie Grønne, Danmarks Nye Venstrefløjsparti, Actual Party: Alternativet
# Candidate: 8, Predicted Party: Radikale Venstre, Actual Party: Løsgænger
# Candidate: 391, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 155, Predicted Party: Danmarksdemokraterne, Actual Party: Dansk Folkeparti
# Candidate: 210, Predicted Party: Alternativet, Actual Party: Radikale Venstre
# Candidate: 396, Predicted Party: Moderaterne, Actual Party: Radikale Venstre
# Candidate: 343, Predicted Party: Venstre, Actual Party: Danmarksdemokraterne
# Candidate: 43, Predicted Party: Enhedslisten, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 500, Predicted Party: Alternativet, Actual Party: Enhedslisten
# Candidate: 816, Predicted Party: Det Konservative Folkeparti, Actual Party: Dansk Folkeparti
# Candidate: 301, Predicted Party: Moderaterne, Actual Party: Radikale Venstre
# Candidate: 126, Predicted Party: Enhedslisten, Actual Party: Alternativet
# Candidate: 250, Predicted Party: Liberal Alliance, Actual Party: Venstre
# Candidate: 710, Predicted Party: Frie Grønne, Danmarks Nye Venstrefløjsparti, Actual Party: Alternativet
# Candidate: 823, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 59, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 219, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 442, Predicted Party: Radikale Venstre, Actual Party: Kristendemokraterne
# Candidate: 289, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 366, Predicted Party: Moderaterne, Actual Party: Kristendemokraterne
# Candidate: 563, Predicted Party: Det Konservative Folkeparti, Actual Party: Nye Borgerlige
# Candidate: 490, Predicted Party: Radikale Venstre, Actual Party: Alternativet
# Candidate: 568, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti

# %%
from sklearn.neighbors import KNeighborsClassifier

# K NEAREST NEIGHBOUR

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Evaluate the model
y_pred = knn.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)

# Predict party affiliations for new candidates
candidatesPartyAffiliationsKNN = knn.predict(X_test)

# Investigate potential misclassifications or candidates in the wrong party
for candidate, predictedParty, actualParty in zip(X_test.index, candidatesPartyAffiliationsKNN, y_test):
   if actualParty != predictedParty:
    print(f"Candidate: {candidate}, Predicted Party: {predictedParty}, Actual Party: {actualParty}")
# Out:
# Accuracy: 0.901840490797546
# Candidate: 519, Predicted Party: Nye Borgerlige, Actual Party: Venstre
# Candidate: 3, Predicted Party: Socialdemokratiet, Actual Party: Alternativet
# Candidate: 782, Predicted Party: Enhedslisten, Actual Party: Alternativet
# Candidate: 92, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 42, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 8, Predicted Party: Radikale Venstre, Actual Party: Løsgænger
# Candidate: 626, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 155, Predicted Party: Danmarksdemokraterne, Actual Party: Dansk Folkeparti
# Candidate: 680, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 763, Predicted Party: Venstre, Actual Party: Det Konservative Folkeparti
# Candidate: 139, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 623, Predicted Party: Danmarksdemokraterne, Actual Party: Venstre
# Candidate: 343, Predicted Party: Venstre, Actual Party: Danmarksdemokraterne
# Candidate: 536, Predicted Party: Det Konservative Folkeparti, Actual Party: Kristendemokraterne
# Candidate: 816, Predicted Party: Det Konservative Folkeparti, Actual Party: Dansk Folkeparti
# Candidate: 126, Predicted Party: Socialistisk Folkeparti, Actual Party: Alternativet
# Candidate: 250, Predicted Party: Liberal Alliance, Actual Party: Venstre
# Candidate: 410, Predicted Party: Moderaterne, Actual Party: Alternativet
# Candidate: 219, Predicted Party: Enhedslisten, Actual Party: Socialdemokratiet
# Candidate: 442, Predicted Party: Moderaterne, Actual Party: Kristendemokraterne
# Candidate: 289, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 366, Predicted Party: Moderaterne, Actual Party: Kristendemokraterne
# Candidate: 417, Predicted Party: Frie Grønne, Danmarks Nye Venstrefløjsparti, Actual Party: Enhedslisten
# Candidate: 651, Predicted Party: Det Konservative Folkeparti, Actual Party: Moderaterne

# %%
from sklearn.svm import SVC

# SVM

svc = SVC()
svc.fit(X_train, y_train)

# Evaluate the model
y_pred = svc.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)

# Predict party affiliations for new candidates
candidatesPartyAffiliationsSVC = svc.predict(X_test)

# Investigate potential misclassifications or candidates in the wrong party
for candidate, predictedParty, actualParty in zip(X_test.index, candidatesPartyAffiliationsSVC, y_test):
   if actualParty != predictedParty:
    print(f"Candidate: {candidate}, Predicted Party: {predictedParty}, Actual Party: {actualParty}")
# Out:
# Accuracy: 0.9570552147239264
# Candidate: 1, Predicted Party: Enhedslisten, Actual Party: Socialistisk Folkeparti
# Candidate: 519, Predicted Party: Nye Borgerlige, Actual Party: Venstre
# Candidate: 3, Predicted Party: Socialdemokratiet, Actual Party: Alternativet
# Candidate: 92, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 42, Predicted Party: Alternativet, Actual Party: Frie Grønne, Danmarks Nye Venstrefløjsparti
# Candidate: 76, Predicted Party: Alternativet, Actual Party: Socialistisk Folkeparti
# Candidate: 8, Predicted Party: Radikale Venstre, Actual Party: Løsgænger
# Candidate: 626, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 139, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 343, Predicted Party: Venstre, Actual Party: Danmarksdemokraterne
# Candidate: 500, Predicted Party: Alternativet, Actual Party: Enhedslisten
# Candidate: 816, Predicted Party: Det Konservative Folkeparti, Actual Party: Dansk Folkeparti
# Candidate: 250, Predicted Party: Det Konservative Folkeparti, Actual Party: Venstre
# Candidate: 219, Predicted Party: Socialistisk Folkeparti, Actual Party: Socialdemokratiet
# Candidate: 442, Predicted Party: Moderaterne, Actual Party: Kristendemokraterne
# Candidate: 289, Predicted Party: Liberal Alliance, Actual Party: Det Konservative Folkeparti
# Candidate: 417, Predicted Party: Frie Grønne, Danmarks Nye Venstrefløjsparti, Actual Party: Enhedslisten
